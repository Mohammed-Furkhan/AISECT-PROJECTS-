# %%
#importing the Libraies
import numpy as np
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('/content/Social_Network_Ads.csv')

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
indep=dataset[['Age', 'EstimatedSalary','Gender_Male']]
dep=dataset['Purchased']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 0.20, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
#https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 10],
    'min_samples_leaf': [1, 5]
}
grid = GridSearchCV(DecisionTreeClassifier(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted')

# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20],
#                          'min_samples_leaf': [1, 5],
#                          'min_samples_split': [2, 10],
#                          'splitter': ['best', 'random']},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)

# %%
# print classification report
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 2, 'splitter': 'random'}: 0.925

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[55  3]
#  [ 3 19]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        58
#            1       0.86      0.86      0.86        22
#
#     accuracy                           0.93        80
#    macro avg       0.91      0.91      0.91        80
# weighted avg       0.93      0.93      0.93        80

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# np.float64(0.978448275862069)

# %%
# Assuming 'grid' is your GridSearchCV object that has been fitted to the data
best_model = grid.best_estimator_

# %%
import pickle
filename="RF_G.sav"
pickle.dump(best_model,open(filename,'wb'))

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.003077      0.000292         0.005764        0.001272
# 1        0.002466      0.000108         0.005355        0.001615
# 2        0.002618      0.000113         0.005116        0.001050
# 3        0.004567      0.002714         0.008213        0.002257
# 4        0.004904      0.002585         0.005750        0.001202
# 5        0.003229      0.001483         0.005054        0.000803
# 6        0.003509      0.001068         0.004657        0.000100
# 7        0.002415      0.000072         0.004845        0.000275
# 8        0.003497      0.001431         0.005122        0.000497
# 9        0.002784      0.000430         0.004920        0.000459
# 10       0.002990      0.000483         0.004760        0.000301
# 11       0.002514      0.000260         0.004839        0.000263
# 12       0.002819      0.000584         0.005143        0.000726
# 13       0.002336      0.000083         0.004623        0.000142
# 14       0.002551      0.000062         0.004532        0.000021
# 15       0.004075      0.003303         0.004747        0.000170
# 16       0.002621      0.000172         0.004499        0.000070
# 17       0.002419      0.000043         0.004620        0.000093
# 18       0.004119      0.002810         0.005790        0.002136
# 19       0.002262      0.000051         0.004549        0.000095
# 20       0.002509      0.000051         0.004579        0.000091
# 21       0.002419      0.000092         0.006248        0.003374
# 22       0.002531      0.000075         0.004567        0.000081
# 23       0.003074      0.001153         0.005174        0.000804
# 24       0.002775      0.000094         0.008428        0.005370
# 25       0.003138      0.001391         0.005668        0.002285
# 26       0.005959      0.003931         0.008725        0.003359
# 27       0.002376      0.000103         0.004538        0.000052
# 28       0.002658      0.000063         0.004608        0.000089
# 29       0.002326      0.000047         0.004944        0.000568
# 30       0.002641      0.000081         0.004602        0.000060
# 31       0.002476      0.000191         0.004747        0.000439
# 32       0.002876      0.000089         0.004589        0.000082
# 33       0.002415      0.000037         0.004501        0.000024
# 34       0.002656      0.000083         0.005306        0.001480
# 35       0.002351      0.000047         0.004843        0.000328
# 36       0.002625      0.000078         0.004662        0.000037
# 37       0.002381      0.000069         0.004556        0.000052
# 38       0.002925      0.000553         0.004973        0.000713
# 39       0.002403      0.000266         0.004635        0.000101
# 40       0.002859      0.000135         0.005044        0.000595
# 41       0.002936      0.000460         0.005534        0.000878
# 42       0.003551      0.001023         0.006369        0.001778
# 43       0.002406      0.000099         0.004563        0.000073
# 44       0.002921      0.000600         0.004914        0.000716
# 45       0.002355      0.000059         0.004844        0.000591
# 46       0.002669      0.000065         0.004924        0.000660
# 47       0.002303      0.000289         0.004520        0.000119
#
#    param_criterion param_max_depth  param_min_samples_leaf  \
# 0             gini            None                       1
# 1             gini            None                       1
# 2             gini            None                       1
# 3             gini            None                       1
# 4             gini            None                       5
# 5             gini            None                       5
# 6             gini            None                       5
# 7             gini            None                       5
# 8             gini              10                       1
# 9             gini              10                       1
# 10            gini              10                       1
# 11            gini              10                       1
# 12            gini              10                       5
# 13            gini              10                       5
# 14            gini              10                       5
# 15            gini              10                       5
# 16            gini              20                       1
# 17            gini              20                       1
# 18            gini              20                       1
# 19            gini              20                       1
# 20            gini              20                       5
# 21            gini              20                       5
# 22            gini              20                       5
# 23            gini              20                       5
# 24         entropy            None                       1
# 25         entropy            None                       1
# 26         entropy            None                       1
# 27         entropy            None                       1
# 28         entropy            None                       5
# 29         entropy            None                       5
# 30         entropy            None                       5
# 31         entropy            None                       5
# 32         entropy              10                       1
# 33         entropy              10                       1
# 34         entropy              10                       1
# 35         entropy              10                       1
# 36         entropy              10                       5
# 37         entropy              10                       5
# 38         entropy              10                       5
# 39         entropy              10                       5
# 40         entropy              20                       1
# 41         entropy              20                       1
# 42         entropy              20                       1
# 43         entropy              20                       1
# 44         entropy              20                       5
# 45         entropy              20                       5
# 46         entropy              20                       5
# 47         entropy              20                       5
#
#     param_min_samples_split param_splitter  \
# 0                         2           best
# 1                         2         random
# 2                        10           best
# 3                        10         random
# 4                         2           best
# 5                         2         random
# 6                        10           best
# 7                        10         random
# 8                         2           best
# 9                         2         random
# 10                       10           best
# 11                       10         random
# 12                        2           best
# 13                        2         random
# 14                       10           best
# 15                       10         random
# 16                        2           best
# 17                        2         random
# 18                       10           best
# 19                       10         random
# 20                        2           best
# 21                        2         random
# 22                       10           best
# 23                       10         random
# 24                        2           best
# 25                        2         random
# 26                       10           best
# 27                       10         random
# 28                        2           best
# 29                        2         random
# 30                       10           best
# 31                       10         random
# 32                        2           best
# 33                        2         random
# 34                       10           best
# 35                       10         random
# 36                        2           best
# 37                        2         random
# 38                       10           best
# 39                       10         random
# 40                        2           best
# 41                        2         random
# 42                       10           best
# 43                       10         random
# 44                        2           best
# 45                        2         random
# 46                       10           best
# 47                       10         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_depth': None, 'min_...           0.860542
# 1   {'criterion': 'gini', 'max_depth': None, 'min_...           0.828694
# 2   {'criterion': 'gini', 'max_depth': None, 'min_...           0.825822
# 3   {'criterion': 'gini', 'max_depth': None, 'min_...           0.844699
# 4   {'criterion': 'gini', 'max_depth': None, 'min_...           0.825822
# 5   {'criterion': 'gini', 'max_depth': None, 'min_...           0.890987
# 6   {'criterion': 'gini', 'max_depth': None, 'min_...           0.825822
# 7   {'criterion': 'gini', 'max_depth': None, 'min_...           0.842448
# 8   {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.828694
# 9   {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.823753
# 10  {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.825822
# 11  {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.857491
# 12  {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.825822
# 13  {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.876251
# 14  {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.825822
# 15  {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.797547
# 16  {'criterion': 'gini', 'max_depth': 20, 'min_sa...           0.860542
# 17  {'criterion': 'gini', 'max_depth': 20, 'min_sa...           0.890201
# 18  {'criterion': 'gini', 'max_depth': 20, 'min_sa...           0.825822
# 19  {'criterion': 'gini', 'max_depth': 20, 'min_sa...           0.825822
# 20  {'criterion': 'gini', 'max_depth': 20, 'min_sa...           0.825822
# 21  {'criterion': 'gini', 'max_depth': 20, 'min_sa...           0.840767
# 22  {'criterion': 'gini', 'max_depth': 20, 'min_sa...           0.825822
# 23  {'criterion': 'gini', 'max_depth': 20, 'min_sa...           0.876251
# 24  {'criterion': 'entropy', 'max_depth': None, 'm...           0.844699
# 25  {'criterion': 'entropy', 'max_depth': None, 'm...           0.858830
# 26  {'criterion': 'entropy', 'max_depth': None, 'm...           0.840767
# 27  {'criterion': 'entropy', 'max_depth': None, 'm...           0.827459
# 28  {'criterion': 'entropy', 'max_depth': None, 'm...           0.840767
# 29  {'criterion': 'entropy', 'max_depth': None, 'm...           0.796088
# 30  {'criterion': 'entropy', 'max_depth': None, 'm...           0.840767
# 31  {'criterion': 'entropy', 'max_depth': None, 'm...           0.875759
# 32  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.827459
# 33  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.843750
# 34  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.840767
# 35  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.890987
# 36  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.840767
# 37  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.891533
# 38  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.840767
# 39  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.751518
# 40  {'criterion': 'entropy', 'max_depth': 20, 'min...           0.844699
# 41  {'criterion': 'entropy', 'max_depth': 20, 'min...           0.828694
# 42  {'criterion': 'entropy', 'max_depth': 20, 'min...           0.840767
# 43  {'criterion': 'entropy', 'max_depth': 20, 'min...           0.890987
# 44  {'criterion': 'entropy', 'max_depth': 20, 'min...           0.840767
# 45  {'criterion': 'entropy', 'max_depth': 20, 'min...           0.845314
# 46  {'criterion': 'entropy', 'max_depth': 20, 'min...           0.840767
# 47  {'criterion': 'entropy', 'max_depth': 20, 'min...           0.812500
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.762048           0.860772           0.844872
# 1            0.747614           0.768868           0.813846
# 2            0.776515           0.843750           0.875000
# 3            0.842259           0.907389           0.891049
# 4            0.858747           0.891049           0.890137
# 5            0.843750           0.842259           0.859920
# 6            0.858747           0.891049           0.890137
# 7            0.810710           0.843750           0.876518
# 8            0.744589           0.860772           0.844872
# 9            0.825502           0.829832           0.875897
# 10           0.776515           0.843750           0.875000
# 11           0.842259           0.922651           0.907389
# 12           0.858747           0.891049           0.890137
# 13           0.808442           0.808442           0.875000
# 14           0.858747           0.891049           0.890137
# 15           0.843750           0.842259           0.830503
# 16           0.744589           0.875897           0.814777
# 17           0.858747           0.815315           0.907389
# 18           0.776515           0.843750           0.875000
# 19           0.875000           0.813846           0.906923
# 20           0.858747           0.891049           0.890137
# 21           0.823187           0.812500           0.906250
# 22           0.858747           0.891049           0.890137
# 23           0.843750           0.827357           0.857229
# 24           0.744589           0.813846           0.876518
# 25           0.722386           0.813846           0.842259
# 26           0.827357           0.843750           0.890137
# 27           0.840368           0.858747           0.906923
# 28           0.857229           0.891049           0.890137
# 29           0.840368           0.825502           0.907389
