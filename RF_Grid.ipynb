# %%
#importing the Libraies
import numpy as np
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('/content/Social_Network_Ads.csv')

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
X=dataset[['Age', 'EstimatedSalary','Gender_Male']]
y=dataset['Purchased']

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
# Create a parameter grid
param_grid = {
    'n_estimators': [50, 100, 200],       # Number of trees
    'max_depth': [None, 5, 10, 20],       # Depth of trees
    'min_samples_split': [2, 5, 10],      # Min samples to split node
    'min_samples_leaf': [1, 2, 5],        # Min samples in leaf
    'bootstrap': [True, False]
}

grid = GridSearchCV(RandomForestClassifier(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted')

# fitting the model for grid search
grid.fit(X, y)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# GridSearchCV(estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'max_depth': [None, 5, 10, 20],
#                          'min_samples_leaf': [1, 2, 5],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(X)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y, grid_predictions)

# %%
# print classification report
from sklearn.metrics import classification_report
clf_report = classification_report(y, grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 50}: 0.9281354681940468

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[236  21]
#  [  8 135]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.92      0.94       257
#            1       0.87      0.94      0.90       143
#
#     accuracy                           0.93       400
#    macro avg       0.92      0.93      0.92       400
# weighted avg       0.93      0.93      0.93       400

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y,grid.predict_proba(X)[:,1])
# Out:
# np.float64(0.9848575548964653)

# %%
# Assuming 'grid' is your GridSearchCV object that has been fitted to the data
best_model = grid.best_estimator_

# %%
import pickle
filename="RF_G.sav"
pickle.dump(best_model,open(filename,'wb'))

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.140383      0.009899         0.013057        0.002660
# 1         0.256309      0.005634         0.022281        0.008434
# 2         0.509491      0.006941         0.029122        0.000306
# 3         0.132431      0.012564         0.010980        0.000509
# 4         0.254611      0.009832         0.020091        0.006079
# ..             ...           ...              ...             ...
# 211       0.192787      0.012041         0.017556        0.000876
# 212       0.370024      0.010621         0.030928        0.003128
# 213       0.092435      0.002635         0.010360        0.000114
# 214       0.184281      0.003400         0.017429        0.000279
# 215       0.366186      0.039182         0.027259        0.005967
#
#      param_bootstrap param_max_depth  param_min_samples_leaf  \
# 0               True            None                       1
# 1               True            None                       1
# 2               True            None                       1
# 3               True            None                       1
# 4               True            None                       1
# ..               ...             ...                     ...
# 211            False              20                       5
# 212            False              20                       5
# 213            False              20                       5
# 214            False              20                       5
# 215            False              20                       5
#
#      param_min_samples_split  param_n_estimators  \
# 0                          2                  50
# 1                          2                 100
# 2                          2                 200
# 3                          5                  50
# 4                          5                 100
# ..                       ...                 ...
# 211                        5                 100
# 212                        5                 200
# 213                       10                  50
# 214                       10                 100
# 215                       10                 200
#
#                                                 params  split0_test_score  \
# 0    {'bootstrap': True, 'max_depth': None, 'min_sa...           0.783072
# 1    {'bootstrap': True, 'max_depth': None, 'min_sa...           0.767183
# 2    {'bootstrap': True, 'max_depth': None, 'min_sa...           0.767183
# 3    {'bootstrap': True, 'max_depth': None, 'min_sa...           0.783072
# 4    {'bootstrap': True, 'max_depth': None, 'min_sa...           0.783072
# ..                                                 ...                ...
# 211  {'bootstrap': False, 'max_depth': 20, 'min_sam...           0.798551
# 212  {'bootstrap': False, 'max_depth': 20, 'min_sam...           0.898006
# 213  {'bootstrap': False, 'max_depth': 20, 'min_sam...           0.798551
# 214  {'bootstrap': False, 'max_depth': 20, 'min_sam...           0.842857
# 215  {'bootstrap': False, 'max_depth': 20, 'min_sam...           0.870909
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0             0.924319           0.859227           0.840551
# 1             0.950000           0.872729           0.840551
# 2             0.925000           0.872729           0.840551
# 3             0.937229           0.899176           0.828357
# 4             0.937229           0.899176           0.828357
# ..                 ...                ...                ...
# 211           0.937229           0.912157           0.816021
# 212           0.937229           0.912157           0.816021
# 213           0.937229           0.911364           0.828357
# 214           0.937229           0.912157           0.816021
# 215           0.937229           0.911364           0.816021
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.815108         0.844455        0.047415              182
# 1             0.802370         0.846567        0.062728              172
# 2             0.815108         0.844114        0.053167              184
# 3             0.875833         0.864733        0.053957              109
# 4             0.863798         0.862326        0.053676              122
# ..                 ...              ...             ...              ...
# 211           0.875833         0.867958        0.053533               92
# 212           0.851777         0.883038        0.043537               46
# 213           0.826167         0.860333        0.053896              135
# 214           0.851000         0.871853        0.045368               80
# 215           0.863798         0.879864        0.041707               53
#
# [216 rows x 18 columns]
