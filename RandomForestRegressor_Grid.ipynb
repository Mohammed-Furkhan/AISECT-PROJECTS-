# %%
#importing the Libraies
import numpy as np
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('/content/insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 0.20, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {
    'n_estimators': [10, 20, 30],
    'max_depth': [None, 10],
    'max_features': ['sqrt', 'log2'],
    'min_samples_split': [2],
    'min_samples_leaf': [1]
}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3 ,n_jobs=-1)
# fitting the model for grid search
grid.fit(X_train, y_train.values.ravel())
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [None, 10],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1], 'min_samples_split': [2],
#                          'n_estimators': [10, 20, 30]},
#              verbose=3)

# %%
# Assuming 'grid' is your GridSearchCV object and has been fitted to the data
print("Best parameters:", grid.best_params_)
# Access the mean test score for the best parameters
best_index = grid.best_index_
best_r2_score = grid.cv_results_['mean_test_score'][best_index]
# Printing the best R² score
print("r2:",best_r2_score)
# Out:
# Best parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 30}
# r2: 0.8189990428163367

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)

# %%
table.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 8        0.412655      0.050541         0.028153        0.013475
# 11       0.324475      0.071520         0.021111        0.009045
# 10       0.285466      0.032434         0.037210        0.015394
# 5        0.120258      0.004627         0.009479        0.000906
# 1        0.088550      0.003881         0.007983        0.000540
# 2        0.131009      0.013401         0.011075        0.001207
# 4        0.086463      0.005402         0.007154        0.000396
# 7        0.165924      0.058182         0.021117        0.006488
# 6        0.039075      0.001708         0.006598        0.003814
# 9        0.180518      0.042112         0.025805        0.010093
# 0        0.048300      0.002999         0.005876        0.000711
# 3        0.047495      0.001664         0.005513        0.000643
#
#     param_bootstrap param_max_depth param_max_features  \
# 8              True              10               sqrt
# 11             True              10               log2
# 10             True              10               log2
# 5              True            None               log2
# 1              True            None               sqrt
# 2              True            None               sqrt
# 4              True            None               log2
# 7              True              10               sqrt
# 6              True              10               sqrt
# 9              True              10               log2
# 0              True            None               sqrt
# 3              True            None               log2
#
#     param_min_samples_leaf  param_min_samples_split  param_n_estimators  \
# 8                        1                        2                  30
# 11                       1                        2                  30
# 10                       1                        2                  20
# 5                        1                        2                  30
# 1                        1                        2                  20
# 2                        1                        2                  30
# 4                        1                        2                  20
# 7                        1                        2                  20
# 6                        1                        2                  10
# 9                        1                        2                  10
# 0                        1                        2                  10
# 3                        1                        2                  10
#
#                                                params  split0_test_score  \
# 8   {'bootstrap': True, 'max_depth': 10, 'max_feat...           0.849899
# 11  {'bootstrap': True, 'max_depth': 10, 'max_feat...           0.852005
# 10  {'bootstrap': True, 'max_depth': 10, 'max_feat...           0.846196
# 5   {'bootstrap': True, 'max_depth': None, 'max_fe...           0.848383
# 1   {'bootstrap': True, 'max_depth': None, 'max_fe...           0.849422
# 2   {'bootstrap': True, 'max_depth': None, 'max_fe...           0.838194
# 4   {'bootstrap': True, 'max_depth': None, 'max_fe...           0.847826
# 7   {'bootstrap': True, 'max_depth': 10, 'max_feat...           0.827449
# 6   {'bootstrap': True, 'max_depth': 10, 'max_feat...           0.829230
# 9   {'bootstrap': True, 'max_depth': 10, 'max_feat...           0.838190
# 0   {'bootstrap': True, 'max_depth': None, 'max_fe...           0.818477
# 3   {'bootstrap': True, 'max_depth': None, 'max_fe...           0.826653
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 8            0.831326           0.801632           0.840139
# 11           0.821725           0.806238           0.839755
# 10           0.814828           0.816345           0.842652
# 5            0.825529           0.794018           0.832900
# 1            0.816351           0.788512           0.833989
# 2            0.817085           0.794997           0.835379
# 4            0.815356           0.784476           0.831787
# 7            0.810240           0.799337           0.827501
# 6            0.815861           0.786964           0.831127
# 9            0.792532           0.798514           0.829600
# 0            0.802140           0.769902           0.823226
# 3            0.792977           0.772329           0.815638
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 8            0.771999         0.818999        0.028511                1
# 11           0.772098         0.818364        0.027886                2
# 10           0.768614         0.817727        0.027764                3
# 5            0.771457         0.814458        0.027858                4
# 1            0.775970         0.812849        0.027383                5
# 2            0.771350         0.811401        0.025291                6
# 4            0.764838         0.808856        0.030393                7
# 7            0.770950         0.807095        0.021011                8
# 6            0.760844         0.804805        0.027065                9
# 9            0.737970         0.799361        0.035322               10
# 0            0.763400         0.795429        0.024602               11
# 3            0.745132         0.790546        0.029440               12

# %%
# Assuming 'grid' is your GridSearchCV object that has been fitted to the data
best_model = grid.best_estimator_

# %%
import pickle
filename="RF_G.sav"
pickle.dump(best_model,open(filename,'wb'))
